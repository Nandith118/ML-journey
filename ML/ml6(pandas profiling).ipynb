# %%
import pandas as pd

# %%
df = pd.read_csv('Titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# !pip install ydata_profiling
# Out:
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.0 MB 5.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/8.0 MB 2.7 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/8.0 MB 4.2 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.0 MB 3.5 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.0 MB 3.9 MB/s eta 0:00:02
#    -------------------------- ------------- 5.2/8.0 MB 4.1 MB/s eta 0:00:01
#    ------------------------------ --------- 6.0/8.0 MB 4.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.0 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 4.0 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/678.1 kB ? eta -:--:--
#    ---------------------------------------- 678.1/678.1 kB 8.3 MB/s  0:00:00
# ...
