# %%
print("Hello")
# Out:
# Hello

# %%
import numpy as np

# %%
arr = np.array(5)

# %%
arr
# Out:
# array(5)

# %%
arr.ndim
# Out:
# 0

# %%
mat = np.array([[1,2],[4,5]])

# %%
mat
# Out:
# array([[1, 2],
#        [4, 5]])

# %%
mat.ndim
# Out:
# 2
